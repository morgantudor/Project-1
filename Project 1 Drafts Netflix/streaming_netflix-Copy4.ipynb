# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
# Define the file path using Path
netflix_titles_csv = Path("C:/Users/leahm/Project-1/netflix_titles.csv")
rotten_tomatoes_csv = Path("C:/Users/leahm/Project-1/netflix-rotten-tomatoes-metacritic-imdb.csv")

# Read the CSV file
netflix_data = pd.read_csv(netflix_titles_csv)
netflix_data.head(5)
# Out:
#   show_id Series or Movie                  Title         Director  \
# 0      s1           Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2         TV Show          Blood & Water              NaN
# 2      s3         TV Show              Ganglands  Julien Leclercq
# 3      s4         TV Show  Jailbirds New Orleans              NaN
# 4      s5         TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                                Genre  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
# Read Rotten Tomatoes CSV
tomatoes_data = pd.read_csv(rotten_tomatoes_csv)
tomatoes_data
# Out:
#                                            Title  \
# 0                               Lets Fight Ghost
# 1                            HOW TO BUILD A GIRL
# 2                                     Centigrade
# 3                                          ANNE+
# 4                                          Moxie
# ...                                          ...
# 15475                     K-POP Extreme Survival
# 15476            DreamWorks Shreks Swamp Stories
# 15477  DreamWorks Happy Holidays from Madagascar
# 15478                DreamWorks Holiday Classics
# 15479   DreamWorks Kung Fu Panda Awesome Secrets
#
#                                         Genre  \
# 0      Crime, Drama, Fantasy, Horror, Romance
# 1                                      Comedy
# 2                             Drama, Thriller
# 3                                       Drama
# 4                     Animation, Short, Drama
# ...                                       ...
# 15475                                     NaN
# 15476                                     NaN
# 15477               Animation, Comedy, Family
# 15478               Animation, Comedy, Family
# 15479       Animation, Action, Comedy, Family
#
#                                                     Tags         Languages  \
# 0      Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1           Dramas,Comedies,Films Based on Books,British           English
# 2                                              Thrillers           English
# 3            TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4      Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
# ...                                                  ...               ...
# 15475  TV Dramas,TV Programmes,TV Comedies,Romantic T...               NaN
# 15476  Animal Tales,Family Comedies,Family Adventures...               NaN
# 15477  TV Comedies,Kids TV,Animal Tales,TV Cartoons,T...           English
# 15478  TV Comedies,Kids TV,TV Cartoons,TV Programmes,...           English
# 15479  TV Comedies,Kids TV,Animal Tales,TV Cartoons,T...           English
#
#       Series or Movie  Hidden Gem Score  \
# 0              Series               4.3
# 1               Movie               7.0
# 2               Movie               6.4
# 3              Series               7.7
# 4               Movie               8.1
# ...               ...               ...
# 15475          Series               NaN
# 15476          Series               NaN
# 15477          Series               8.4
# 15478          Series               8.2
# 15479          Series               8.1
#
#                                     Country Availability       Runtime  \
# 0                                               Thailand  < 30 minutes
# 1                                                 Canada      1-2 hour
# 2                                                 Canada      1-2 hour
# 3                                    Belgium,Netherlands  < 30 minutes
# 4      Lithuania,Poland,France,Iceland,Italy,Spain,Gr...      1-2 hour
# ...                                                  ...           ...
# 15475  South Korea,Argentina,United Kingdom,Australia...  < 30 minutes
# 15476  Russia,Hong Kong,Hungary,Australia,South Korea...  < 30 minutes
# 15477  Belgium,Switzerland,United States,Germany,Unit...  < 30 minutes
# 15478  Belgium,Switzerland,Germany,Argentina,United K...  < 30 minutes
# 15479  Belgium,Switzerland,Germany,United Kingdom,Fra...  < 30 minutes
#
#               Director                      Writer  ... Netflix Release Date  \
# 0      Tomas Alfredson       John Ajvide Lindqvist  ...           2021-03-04
# 1        Coky Giedroyc               Caitlin Moran  ...           2021-03-04
# 2        Brendan Walsh  Brendan Walsh, Daley Nixon  ...           2021-03-04
# 3                  NaN                         NaN  ...           2021-03-04
# 4        Stephen Irwin                         NaN  ...           2021-03-04
# ...                ...                         ...  ...                  ...
# 15475              NaN                         NaN  ...           2015-04-14
# 15476              NaN                         NaN  ...           2015-04-14
# 15477              NaN                         NaN  ...           2015-04-14
# 15478              NaN                         NaN  ...           2015-04-14
# 15479              NaN                         NaN  ...           2015-04-14
#
#                              Production House  \
# 0                   Canal+, Sandrew Metronome
# 1      Film 4, Monumental Pictures, Lionsgate
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 15475                                     NaN
# 15476                                     NaN
# 15477                                     NaN
# 15478                                     Fox
# 15479                                     NaN
#
#                                  Netflix Link  \
# 0      https://www.netflix.com/watch/81415947
# 1      https://www.netflix.com/watch/81041267
# 2      https://www.netflix.com/watch/81305978
# 3      https://www.netflix.com/watch/81336456
# 4      https://www.netflix.com/watch/81078393
# ...                                       ...
# 15475  https://www.netflix.com/watch/80031595
# 15476  https://www.netflix.com/watch/70242630
# 15477  https://www.netflix.com/watch/70259784
# 15478  https://www.netflix.com/watch/70221348
# 15479  https://www.netflix.com/watch/70241791
#
#                                   IMDb Link  \
# 0      https://www.imdb.com/title/tt1139797
# 1      https://www.imdb.com/title/tt4193072
# 2      https://www.imdb.com/title/tt8945942
# 3      https://www.imdb.com/title/tt6132758
# 4      https://www.imdb.com/title/tt2023611
# ...                                     ...
# 15475                                   NaN
# 15476                                   NaN
# 15477                                   NaN
# 15478                                   NaN
# 15479                                   NaN
#
#                                                  Summary  IMDb Votes  \
# 0      A med student with a supernatural gift tries t...    205926.0
# 1      When nerdy Johanna moves to London, things get...      2838.0
# 2      Trapped in a frozen car during a blizzard, a p...      1720.0
# 3      Upon moving into a new place, a 20-something r...      1147.0
# 4      Inspired by her moms rebellious past and a con...        63.0
# ...                                                  ...         ...
# 15475  Seung Yeon decides to chase her dream of becom...         NaN
# 15476  Shrek celebrates Halloween, Puss in Boots is c...         NaN
# 15477  Madagascar goes wild with holiday spirit in th...        71.0
# 15478  Join your DreamWorks friends for these four ho...        82.0
# 15479  In this pair of adventures, Po tells the story...        17.0
#
#                                                    Image  \
# 0      https://occ-0-4708-64.1.nflxso.net/dnm/api/v6/...
# 1      https://occ-0-1081-999.1.nflxso.net/dnm/api/v6...
# 2      https://occ-0-1081-999.1.nflxso.net/dnm/api/v6...
# 3      https://occ-0-1489-1490.1.nflxso.net/dnm/api/v...
# 4      https://occ-0-4039-1500.1.nflxso.net/dnm/api/v...
# ...                                                  ...
# 15475  https://occ-0-2851-38.1.nflxso.net/dnm/api/v6/...
# 15476  https://occ-0-2851-38.1.nflxso.net/dnm/api/v6/...
# 15477  https://occ-0-2773-2774.1.nflxso.net/dnm/api/v...
# 15478  https://occ-0-2851-38.1.nflxso.net/dnm/api/v6/...
# 15479  https://occ-0-2851-38.1.nflxso.net/dnm/api/v6/...
#
#                                                   Poster  \
# 0      https://m.media-amazon.com/images/M/MV5BOWM4NT...
# 1      https://m.media-amazon.com/images/M/MV5BZGUyN2...
# 2      https://m.media-amazon.com/images/M/MV5BODM2MD...
# 3      https://m.media-amazon.com/images/M/MV5BNWRkMz...
# 4      https://m.media-amazon.com/images/M/MV5BODYyNW...
# ...                                                  ...
# 15475                                                NaN
# 15476                                                NaN
# 15477                                                NaN
# 15478                                                NaN
# 15479                                                NaN
#
#                                       TMDb Trailer Trailer Site
# 0                                              NaN          NaN
# 1      https://www.youtube.com/watch?v=eIbcxPy4okQ      YouTube
# 2      https://www.youtube.com/watch?v=0RvV7TNUlkQ      YouTube
# 3                                              NaN          NaN
# 4                                              NaN          NaN
# ...                                            ...          ...
# 15475                                          NaN          NaN
# 15476                                          NaN          NaN
# 15477                                          NaN          NaN
# 15478                                          NaN          NaN
# 15479                                          NaN          NaN
#
# [15480 rows x 29 columns]

# %%
print(tomatoes_data.columns)
# Out:
# Index(['Title', 'Genre', 'Tags', 'Languages', 'Series or Movie',
#        'Hidden Gem Score', 'Country Availability', 'Runtime', 'Director',
#        'Writer', 'Actors', 'View Rating', 'IMDb Score',
#        'Rotten Tomatoes Score', 'Metacritic Score', 'Awards Received',
#        'Awards Nominated For', 'Boxoffice', 'Release Date',
#        'Netflix Release Date', 'Production House', 'Netflix Link', 'IMDb Link',
#        'Summary', 'IMDb Votes', 'Image', 'Poster', 'TMDb Trailer',
#        'Trailer Site'],
#       dtype='object')

# %%
genre_count, = plt.plot(tomatoes_data['Genre'], color="blue", label="Genres")

# Plot viewer ratings based on Release Year for Series and Movies
series_data = tomatoes_data[tomatoes_data['Series or Movie'] == 'Series']
movie_data = tomatoes_data[tomatoes_data['Series or Movie'] == 'Movie']

plt.plot(series_data['Genre'], series_data['Series or Movie'], color="green", label="Series")
plt.plot(movie_data['Genre'], movie_data['Series or Movie'], color="red", label="Movies")

# Create a legend for the chart
plt.legend(loc="best")

# Set labels for the plot
plt.xlabel("Release Year")
plt.ylabel("Rotten Tomatoes Score")

# Show the chart
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 genre_count, = plt.plot(tomatoes_data['Genre'], color="blue", label="Genres")
#       3 # Plot viewer ratings based on Release Year for Series and Movies
#       4 series_data = tomatoes_data[tomatoes_data['Series or Movie'] == 'Series']
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:501, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     499     self.axes.xaxis.update_units(x)
#     500 if self.axes.yaxis is not None:
# --> 501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
#     504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axis.py:1675, in Axis.update_units(self, data)
#    1673 neednew = self.converter != converter
#    1674 self.converter = converter
# -> 1675 default = self.converter.default_units(data, self)
#    1676 if default is not None and self.units is None:
#    1677     self.set_units(default)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\category.py:105, in StrCategoryConverter.default_units(data, axis)
#     103 # the conversion call stack is default_units -> axis_info -> convert
#     104 if axis.units is None:
# --> 105     axis.set_units(UnitData(data))
#     106 else:
#     107     axis.units.update(data)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\category.py:181, in UnitData.__init__(self, data)
#     179 self._counter = itertools.count()
#     180 if data is not None:
# --> 181     self.update(data)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\category.py:216, in UnitData.update(self, data)
#     213 convertible = True
#     214 for val in OrderedDict.fromkeys(data):
#     215     # OrderedDict just iterates over unique values in data.
# --> 216     _api.check_isinstance((str, bytes), value=val)
#     217     if convertible:
#     218         # this will only be called so long as convertible is True.
#     219         convertible = self._str_is_convertible(val)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_api\__init__.py:93, in check_isinstance(_types, **kwargs)
#      91     names.remove("None")
#      92     names.append("None")
# ---> 93 raise TypeError(
#      94     "{!r} must be an instance of {}, not a {}".format(
#      95         k,
#      96         ", ".join(names[:-1]) + " or " + names[-1]
#      97         if len(names) > 1 else names[0],
#      98         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a float

# %%
columns_to_delete = ['Netflix Release Date','Production House','Netflix Link','IMDb Link','Summary','IMDb Votes','Image','Poster','TMDb Trailer']

# Use the 'drop' method to remove the specified columns and assign the result back to the DataFrame
tomatoes_data = tomatoes_data.drop(columns=columns_to_delete)

# %%
print(tomatoes_data.columns)
# Out:
# Index(['Title', 'Genre', 'Tags', 'Languages', 'Series or Movie',
#        'Hidden Gem Score', 'Country Availability', 'Runtime', 'Director',
#        'Writer', 'Actors', 'View Rating', 'IMDb Score',
#        'Rotten Tomatoes Score', 'Metacritic Score', 'Awards Received',
#        'Awards Nominated For', 'Boxoffice', 'Release Date',
#        'Netflix Release Date', 'Production House', 'Netflix Link', 'IMDb Link',
#        'Summary', 'IMDb Votes', 'Image', 'Poster', 'TMDb Trailer',
#        'Trailer Site'],
#       dtype='object')

# %%
print(netflix_data).columns

# %%
release_year_df = netflix_data.groupby('release_year')
release_year_count = release_year_df['release_year'].count()
release_chart = release_year_count.plot(kind="bar", title="Netflix Video Movies/Shows Sorted by Release Year", figsize=(25,10))
release_chart.set_xlabel("Release Year")
release_chart.set_ylabel("Number of Movies/Show Released")
plt.show()

# %%
# merging netflix and tomatoes data sets
netflix_tomatoes_data = pd.merge(netflix_data, tomatoes_data, how="left", on=['Title','Series or Movie','Genre'])
netflix_tomatoes_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 2
#       1 # merging netflix and tomatoes data sets
# ----> 2 netflix_tomatoes_data = pd.merge(netflix_data, tomatoes_data, how="left", on=['Title','Series or Movie','Genre'])
#       3 netflix_tomatoes_data.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
#     121         indicator=indicator,
#     122         validate=validate,
#     123     )
#     124     return op.get_result(copy=copy)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:703, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     696 self._cross = cross_col
#     698 # note this function has side effects
#     699 (
#     700     self.left_join_keys,
#     701     self.right_join_keys,
#     702     self.join_names,
# --> 703 ) = self._get_merge_keys()
#     705 # validate the merge keys dtypes. We may need to coerce
#     706 # to avoid incompatible dtypes
#     707 self._maybe_coerce_merge_keys()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:1162, in _MergeOperation._get_merge_keys(self)
#    1160 rk = cast(Hashable, rk)
#    1161 if rk is not None:
# -> 1162     right_keys.append(right._get_label_or_level_values(rk))
#    1163 else:
#    1164     # work-around for merge_asof(right_index=True)
#    1165     right_keys.append(right.index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:1850, in NDFrame._get_label_or_level_values(self, key, axis)
#    1844     values = (
#    1845         self.axes[axis]
#    1846         .get_level_values(key)  # type: ignore[assignment]
#    1847         ._values
#    1848     )
#    1849 else:
# -> 1850     raise KeyError(key)
#    1852 # Check for duplicates
#    1853 if values.ndim > 1:
#
# KeyError: 'Title'

# %%
# Calculate the total number of movies
title_count = len(netflix_tomatoes_data["Title"].unique())
title_count

# %%
# Calculate the total number tv shows
genre_count = len(netflix_tomatoes_data["Genre"].unique())
genre_count

# %%
scores_df = tomatoes_data[['Rotten Tomatoes Score', 'Metacritic Score', 'Awards Received', 'Awards Nominated For']]
scores_df = scores_df.fillna('')
scores_df
# Out:
#       Rotten Tomatoes Score Metacritic Score Awards Received  \
# 0                      98.0             82.0            74.0
# 1                      79.0             69.0             1.0
# 2                                       46.0
# 3                                                        1.0
# 4
# ...                     ...              ...             ...
# 15475
# 15476
# 15477
# 15478
# 15479
#
#       Awards Nominated For
# 0                     57.0
# 1
# 2
# 3
# 4                      4.0
# ...                    ...
# 15475
# 15476
# 15477
# 15478
# 15479
#
# [15480 rows x 4 columns]

# %%
# Create a group based on the values in the 'director' column
director_data =tomatoes_data.groupby('Director')

# Count how many times each road type appears in our group
awards_data = director_data['Awards Received'].count()

awards_data
# Out:
# Director
# A. Rajdeep          0
# A. Salaam           0
# A.L. Vijay          1
# A.R. Murugadoss     2
# Aamir Bashir        1
#                    ..
# Óscar Menéndez      0
# Ömer Faruk Sorak    2
# Ömer Ugur           0
# Ömer Vargi          1
# Özcan Deniz         0
# Name: Awards Received, Length: 6746, dtype: int64

# %%
score_counts = tomatoes_data.groupby['Rotten Tomatoes Score'].value_counts()
release_year_count = score_counts['Genre'].count()
plt.bar(counts.index.values,counts.values)
plt.xlabel('Genre')
plt.xticks(rotation=90)
plt.ylabel('Series or Movie')
plt.title('Rotten Tomatoes Score')
plt.show()


release_year_df = netflix_data.groupby('release_year')
release_year_count = release_year_df['release_year'].count()
release_chart = release_year_count.plot(kind="bar", title="Netflix Video Movies/Shows Sorted by Release Year", figsize=(25,10))
release_chart.set_xlabel("Release Year")
release_chart.set_ylabel("Number of Movies/Show Released")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 score_counts = tomatoes_data.groupby['Rotten Tomatoes Score'].value_counts()
#       2 release_year_count = score_counts['Genre'].count()
#       3 plt.bar(counts.index.values,counts.values)
#
# TypeError: 'method' object is not subscriptable

# %%
score_counts = tomatoes_data['Rotten Tomatoes Score'].value_counts()

# Create a bar chart
plt.figure(figsize=(12, 6))
plt.bar(score_counts.index, score_counts.values)
plt.xlabel('Rotten Tomatoes Score')
plt.ylabel('Frequency')
plt.title('Rotten Tomatoes Score Distribution')
plt.xticks(rotation=90)  # Rotate the x-axis labels for better readability
plt.show()

# %%
genre_data_df = netflix_data.groupby(['country'])
netflix_data = netflix_data.drop_duplicates(subset=['country'])
netflix_data_Score_count = genre_data_df['Genre'].count()
netflix_data = netflix_data.drop_duplicates(subset=['Genre'])
netflix_data_Score_chart = netflix_data_Score_count.plot(kind="bar", title="Netflix Sorted Genre", figsize=(25,10))
release_chart.set_xlabel("country")
release_chart.set_ylabel("Genre")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 6
#       4 netflix_data = netflix_data.drop_duplicates(subset=['Genre'])
#       5 netflix_data_Score_chart = netflix_data_Score_count.plot(kind="bar", title="Netflix Sorted Genre", figsize=(25,10))
# ----> 6 release_chart.set_xlabel("country")
#       7 release_chart.set_ylabel("Genre")
#       8 plt.show()
#
# NameError: name 'release_chart' is not defined

# %%
counts = tomatoes_data['Awards Received'].value_counts()
plt.bar(counts.index.values,counts.values)
plt.xlabel('Release Date')
plt.xticks(rotation=90)
plt.ylabel('Series or Movie')
plt.show()

# %%
Release_Date_df = tomatoes_data.groupby('Release_Date')
Release_Date_count = Release_Date_df['Release_Date'].count()
release_chart = Release_Date_count.plot(kind="bar", title="Tomatoes Movies/Shows Data Sorted by Release Year", figsize=(25,10))
release_chart.set_xlabel("Release Date")
release_chart.set_ylabel("Number of Movies/Show Released")
plt.savefig("Images/Tomatoes_by_Release_Date.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 Release_Date_df = tomatoes_data.groupby('Release_Date')
#       2 Release_Date_count = Release_Date_df['Release_Date'].count()
#       3 release_chart = Release_Date_count.plot(kind="bar", title="Tomatoes Movies/Shows Data Sorted by Release Year", figsize=(25,10))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
#    8407     as_index=as_index,
#    8408     sort=sort,
#    8409     group_keys=group_keys,
#    8410     squeeze=squeeze,
#    8411     observed=observed,
#    8412     dropna=dropna,
#    8413 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:965, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     962 if grouper is None:
#     963     from pandas.core.groupby.grouper import get_grouper
# --> 965     grouper, exclusions, obj = get_grouper(
#     966         obj,
#     967         keys,
#     968         axis=axis,
#     969         level=level,
#     970         sort=sort,
#     971         observed=observed,
#     972         mutated=self.mutated,
#     973         dropna=self.dropna,
#     974     )
#     976 self.obj = obj
#     977 self.axis = obj._get_axis_number(axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:888, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     886         in_axis, level, gpr = False, gpr, None
#     887     else:
# --> 888         raise KeyError(gpr)
#     889 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     890     # Add key to exclusions
#     891     exclusions.add(gpr.key)
#
# KeyError: 'Release_Date'

# %%
Release_Date_df = tomatoes_data.groupby('Release_Date')
Release_Date_count = Release_Date_df['Release_Date'].count()

# Create a bar chart
release_chart = Release_Date_count.plot(kind="bar", title="Tomatoes Movies/Shows Data Sorted by Release Year", figsize=(25, 10))

# Set labels for the x-axis and y-axis
release_chart.set_xlabel("Release Date")
release_chart.set_ylabel("Number of Movies/Shows Released")

# Save the chart as an image
plt.savefig("Images/Tomatoes_by_Release_Date.png")

# Show the chart
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 Release_Date_df = tomatoes_data.groupby('Release_Date')
#       2 Release_Date_count = Release_Date_df['Release_Date'].count()
#       4 # Create a bar chart
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
#    8407     as_index=as_index,
#    8408     sort=sort,
#    8409     group_keys=group_keys,
#    8410     squeeze=squeeze,
#    8411     observed=observed,
#    8412     dropna=dropna,
#    8413 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:965, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     962 if grouper is None:
#     963     from pandas.core.groupby.grouper import get_grouper
# --> 965     grouper, exclusions, obj = get_grouper(
#     966         obj,
#     967         keys,
#     968         axis=axis,
#     969         level=level,
#     970         sort=sort,
#     971         observed=observed,
#     972         mutated=self.mutated,
#     973         dropna=self.dropna,
#     974     )
#     976 self.obj = obj
#     977 self.axis = obj._get_axis_number(axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:888, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     886         in_axis, level, gpr = False, gpr, None
#     887     else:
# --> 888         raise KeyError(gpr)
#     889 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     890     # Add key to exclusions
#     891     exclusions.add(gpr.key)
#
# KeyError: 'Release_Date'

# %%
movie_data = [0]  # Assign a numerical value for "Movie"
series_data = [1]  # Assign a numerical value for "Series/TV Show"
labels = ["Data Point 1"]
widths = 100  # Set the width of the markers

# Create a figure and axis
fig, ax1 = plt.subplots()

# Scatter plot with x and y data
scatter = ax1.scatter(movie_data, series_data, c='blue', cmap='viridis', s=widths)

# Set labels and title
ax1.set_ylabel('Series/TV Show')
ax1.set_xlabel("Movies")

# Set x and y tick labels to match the categories

# Add a colorbar with labels
cbar = plt.colorbar(scatter, ax=ax1)
cbar.set_label('Labels')

plt.show()
# Out:
# C:\Users\leahm\AppData\Local\Temp\ipykernel_14252\2189193156.py:10: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax1.scatter(movie_data, series_data, c='blue', cmap='viridis', s=widths)

# %%
columns_to_print = netflix_tomatoes_data["Genre"]
print(column_to_print)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 columns_to_print = netflix_tomatoes_data["Genre"]
#       2 print(column_to_print)
#
# NameError: name 'netflix_tomatoes_data' is not defined

# %%
#genre types in netflix data 
genre_types = netflix_tomatoes_data[["Genre",]].set_index("Genre")
genre_types
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 #genre types in netflix data
# ----> 2 genre_types = netflix_tomatoes_data[["Genre",]].set_index("Genre")
#       3 genre_types
#
# NameError: name 'netflix_tomatoes_data' is not defined

# %%
genres = ['Documentaries', 'International', 'Dramas', 'Comedies', 'Horror', 'Musicals']
subset_data = netflix_tomatoes_data[netflix_tomatoes_data['Genre'].isin(genres)]
counts = subset_data['Genre'].value_counts()

# Plot the bar chart
plt.bar(counts.index, counts.values)
plt.xlabel('Genres')
plt.ylabel('Count')
plt.title('Genres')
plt.xticks(rotation=45)  # Rotating x-axis labels for better visibility
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 genres = ['Documentaries', 'International', 'Dramas', 'Comedies', 'Horror', 'Musicals']
# ----> 2 subset_data = netflix_tomatoes_data[netflix_tomatoes_data['Genre'].isin(genres)]
#       3 counts = subset_data['Genre'].value_counts()
#       5 # Plot the bar chart
#
# NameError: name 'netflix_tomatoes_data' is not defined

# %%
#create a bar chart listing the genre types in each data set 
counts = netflix_tomatoes_data["Series or Movie"].value_counts()
plt.bar(counts.index.values,counts.values)
plt.xlabel('Series or Movie')
plt.xticks(rotation=90)
plt.ylabel('Genre')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 #create a bar chart listing the genre types in each data set
# ----> 2 counts = netflix_tomatoes_data["Series or Movie"].value_counts()
#       3 plt.bar(counts.index.values,counts.values)
#       4 plt.xlabel('Series or Movie')
#
# NameError: name 'netflix_tomatoes_data' is not defined

# %%
# genre types in tomatoes data
genre_tom_types = tomatoes_data[["Genre", "Series or Movie"]].set_index("Genre")["Series or Movie"]
genre_tom_types
# Out:
# Genre
# Crime, Drama, Fantasy, Horror, Romance    Series
# Comedy                                     Movie
# Drama, Thriller                            Movie
# Drama                                     Series
# Animation, Short, Drama                    Movie
#                                            ...
# NaN                                       Series
# NaN                                       Series
# Animation, Comedy, Family                 Series
# Animation, Comedy, Family                 Series
# Animation, Action, Comedy, Family         Series
# Name: Series or Movie, Length: 15480, dtype: object

# %%
#genre types in both data combined
# Checking the number of genres in the clean DataFrame.
genre_netflix_types = netflix_data[['Genre', "Series or Movie"]].set_index('Genre')["Series or Movie"]
genre_netflix_types

# %%
netflix_tomatoes_data.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 netflix_tomatoes_data.columns
#
# NameError: name 'netflix_tomatoes_data' is not defined

# %%
# Generate a pie plot showing the distribution of Series or Movie and listed_in using pyplot
counts = netflix_tomatoes_data["Series or Movie"].value_counts()
plt.pie(counts.values, labels=counts.index.values, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Two Main Categories")
plt.xlabel("Series")
plt.ylabel("TV show")
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Generate a pie plot showing the distribution of Series or Movie and listed_in using pyplot
# ----> 2 counts = netflix_tomatoes_data["Series or Movie"].value_counts()
#       3 plt.pie(counts.values, labels=counts.index.values, autopct='%1.1f%%', shadow=True, startangle=140)
#       4 plt.title("Two Main Categories")
#
# NameError: name 'netflix_tomatoes_data' is not defined

# %%
# Define your DataFrame (replace this with your actual DataFrame)
tomatoes_data = pd.DataFrame({
    'Genre': ['Drama', 'Comedy', 'Horror', 'Action'],
    'Drama': [1, 0, 0, 0],
    'Comedy': [0, 1, 0, 0],
    'Horror': [0, 0, 1, 0],
    'Action': [0, 0, 0, 1]
})

# Specify the genre you want to analyze (e.g., 'Crime' in your case)
genre_type = 'Drama','Comedy'

# Check if the genre exists in the DataFrame
if genre_type in netflix_tomatoes_data.columns:
    # Calculate lower and upper bounds (you should have these values defined)
    lower_bound = 0
    upper_bound = 1

    # Identify outliers for the specified genre
    outliers = netflix_tomatoes_data[
        (tomatoes_data['Genre'] == genre_type) &
        ((tomatoes_data[genre_type] < lower_bound) | (tomatoes_data[genre_type] > upper_bound))
    ]

    # Create a new column to mark outliers for that genre
    tomatoes_data[genre_type + '_outlier'] = False
    tomatoes_data.loc[outliers.index, genre_type + '_outlier'] = True
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 14
#      11 genre_type = 'Drama','Comedy'
#      13 # Check if the genre exists in the DataFrame
# ---> 14 if genre_type in netflix_tomatoes_data.columns:
#      15     # Calculate lower and upper bounds (you should have these values defined)
#      16     lower_bound = 0
#      17     upper_bound = 1
#
# NameError: name 'netflix_tomatoes_data' is not defined

# %%
# Generate a box plot that shows movies and what genres they're in 
# Dramas, Thrillers, Horror, and Comedy

Drama_movies = netflix_tomatoes_data [netflix_tomatoes_data['description'] == "Drama_movies"]["Genre"]
Thriller_movies = netflix_tomatoes_data [netflix_tomatoes_data['description'] == "Thriller_movies"]["Genre"]
Horror_movies =netflix_tomatoes_data [netflix_tomatoes_data['description'] == "Horror_movies"]["Genre"]
Comedy_movies = netflix_tomatoes_data [netflix_tomatoes_data['description'] == "Comedy_movies"]["Genre"]


# Create a list of tumor volume data for each treatment group
movie_data = [Drama_movies, Thriller_movies, Horror_movies, Comedy_movies]

# Create a boxplot
plt.boxplot(movie_data, showmeans=True)
plt.grid(True)
plt.title("Movie Types")
plt.ylabel('Genre')
plt.xticks([1, 2, 3, 4], ["Drama_movies", "Thriller_movies", "Horror_movies", "Comedy_movies"])
plt.show()

# %%
# Calculate the average rating per type
count_by_listed_in = netflix_data['rating'].value_counts()
count_by_listed_in

# %%
# Generate a bar plot showing the total number of rows (Genre/listed_in) using pyplot.

counts = netflix_tomatoes_data['rating'].value_counts()
plt.bar(counts.index.values,counts.values)
plt.xlabel('rating')
plt.xticks(rotation=90)
plt.ylabel("listed_in")
plt.show()

# %%
count_by_type = netflix_data['Series or Movie'].value_counts()
count_by_type

# %%
count_tom_type = tomatoes_data['Series or Movie'].value_counts()
count_tom_type

# %%
Drama_movies = netflix_tomatoes_data[netflix_tomatoes_data['Genre'] == "Drama_movies"]
Thriller_movies = netflix_tomatoes_data[netflix_tomatoes_data['Genre'] == "Thriller_movies"]
Horror_movies = netflix_tomatoes_data[netflix_tomatoes_data['Genre'] == "Horror_movies"]
Comedy_movies = netflix_tomatoes_data[netflix_tomatoes_data['Genre'] == "Comedy_movies"]

# Create a bar plot to visualize the counts
genre_counts = [len(Drama_movies), len(Thriller_movies), len(Horror_movies), len(Comedy_movies)]
genres = ['Drama_movies', 'Thriller_movies', 'Horror_movies', 'Comedy_movies']


plt.bar(counts.index.values,counts.values)
# Set labels and title
plt.xlabel('Genre')
plt.ylabel('Count')
plt.title('Count of Movies in Different Genres')

# Show the plot

# %%
genre_data = [
    {'Genre': 'Drama'},
    {'Genre': 'Comedy'},
    {'Genre': 'Action'},
    {'Genre': 'Thriller'},
    {'Genre': 'Horror'},
    # Add more data as needed
]

# Convert the list of dictionaries to a DataFrame
tomatoes_data = pd.DataFrame(genre_data)

# Calculate the genre counts
genre_counts = tomatoes_data['Genre'].value_counts()

# Create a line plot
plt.figure(figsize=(10, 6))
genre_counts.pie(kind='pie', marker='o', linestyle='-', color='b')

# Set labels
plt.xlabel("Genre")
plt.ylabel("Count")

# Optionally, set the x-axis ticks to match your data
plt.xticks(rotation=90)

# Show the plot
plt.show()

# %%
genre_counts = [len(Drama_movies), len(Thriller_movies), len(Horror_movies), len(Comedy_movies)]
genres = ['Drama_movies', 'Thriller_movies', 'Horror_movies', 'Comedy_movies']

# Create a pie chart
plt.figure(figsize=(10, 6))
plt.pie(genre_counts, labels=genre_counts.index, autopct='%1.1f%%', startangle=140, colors=['b', 'g', 'r', 'c', 'm', 'y'])
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Set a title
plt.title('Genre Distribution on Netflix')

# Show the pie chart
plt.show()

# %%
specific_genres = ['Comedy', 'Drama', 'Romance', 'Documentary', 'Family']

# Filter the DataFrame to include only the specified genres
filtered_data = tomatoes_data[tomatoes_data['Genre'].isin(specific_genres)]

# Create a pie chart
plt.figure(figsize=(30, 15))
genre_counts = filtered_data['Genre'].value_counts()
plt.pie(genre_counts, labels=genre_counts.index, autopct='%1.1f%%', startangle=140, colors=['g','y', 'm', 'r', 'c'])
plt.axis('equal')  # Equal aspect ratio ensures that the pie is drawn as a circle.

# Set a title
plt.title('Genre Distribution on Netflix')

# Show the pie chart
plt.show()

# %%
release_year_df = netflix_data.groupby('release_year')
release_year_count = release_year_df['release_year'].count()
release_chart = release_year_count.plot(kind="bar", title="Netflix Video Movies/Shows Sorted by Release Year", figsize=(25,10))
release_chart.set_xlabel("Release Year")
release_chart.set_ylabel("Number of Movies/Show Released")
plt.show()

# %%
genre_counts = [len(Drama_movies), len(Thriller_movies), len(Horror_movies), len(Comedy_movies)]
genres = ['Drama_movies', 'Thriller_movies', 'Horror_movies', 'Comedy_movies']

# Create a pie chart
plt.figure(figsize=(10, 6))
plt.pie(genre_counts, labels=genres, autopct='%1.1f%%', startangle=140, colors=['b', 'g', 'r', 'c'])
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Set a title
plt.title('Genre Distribution on Netflix')

# Show the pie chart
plt.show()
