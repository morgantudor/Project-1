# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
# Define the file path using Path
netflix_titles_csv = Path("C:/Users/leahm/Project-1/netflix_titles.csv")
rotten_tomatoes_csv = Path("C:/Users/leahm/Project-1/netflix-rotten-tomatoes-metacritic-imdb.csv")

# Read the CSV file
netflix_data = pd.read_csv(netflix_titles_csv)
netflix_data.head(5)
# Out:
#   show_id Series or Movie                  Title         director  \
# 0      s1           Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2         TV Show          Blood & Water              NaN
# 2      s3         TV Show              Ganglands  Julien Leclercq
# 3      s4         TV Show  Jailbirds New Orleans              NaN
# 4      s5         TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# ...

# %%
# Read Rotten Tomatoes CSV
tomatoes_data = pd.read_csv(rotten_tomatoes_csv)
tomatoes_data
# Out:
#                                            Title  \
# 0                               Lets Fight Ghost
# 1                            HOW TO BUILD A GIRL
# 2                                     Centigrade
# 3                                          ANNE+
# 4                                          Moxie
# ...                                          ...
# 15475                     K-POP Extreme Survival
# 15476            DreamWorks Shreks Swamp Stories
# 15477  DreamWorks Happy Holidays from Madagascar
# 15478                DreamWorks Holiday Classics
# 15479   DreamWorks Kung Fu Panda Awesome Secrets
#
#                                         Genre  \
# 0      Crime, Drama, Fantasy, Horror, Romance
# 1                                      Comedy
# 2                             Drama, Thriller
# 3                                       Drama
# 4                     Animation, Short, Drama
# ...                                       ...
# ...

# %%
print(tomatoes_data.columns)
# Out:
# Index(['Title', 'Genre', 'Tags', 'Languages', 'Series or Movie',
#        'Hidden Gem Score', 'Country Availability', 'Runtime', 'Director',
#        'Writer', 'Actors', 'View Rating', 'IMDb Score',
#        'Rotten Tomatoes Score', 'Metacritic Score', 'Awards Received',
#        'Awards Nominated For', 'Boxoffice', 'Release Date',
#        'Netflix Release Date', 'Production House', 'Netflix Link', 'IMDb Link',
#        'Summary', 'IMDb Votes', 'Image', 'Poster', 'TMDb Trailer',
#        'Trailer Site'],
#       dtype='object')

# %%
columns_to_delete = ['Netflix Release Date','Production House','Netflix Link','IMDb Link','Summary','IMDb Votes','Image','Poster','TMDb Trailer']

# Use the 'drop' method to remove the specified columns and assign the result back to the DataFrame
tomatoes_data = tomatoes_data.drop(columns=columns_to_delete)

# %%
print(tomatoes_data.columns)
# Out:
# Index(['Title', 'Genre', 'Tags', 'Languages', 'Series or Movie',
#        'Hidden Gem Score', 'Country Availability', 'Runtime', 'Director',
#        'Writer', 'Actors', 'View Rating', 'IMDb Score',
#        'Rotten Tomatoes Score', 'Metacritic Score', 'Awards Received',
#        'Awards Nominated For', 'Boxoffice', 'Release Date', 'Trailer Site'],
#       dtype='object')

# %%
# Stack the DataFrame and reset the index
selected_genre_df = tomatoes_data.stack().reset_index()

# Access columns using double square brackets
selected_columns = selected_genre_df[['Series or Movie','column','Genre']]

# Filter rows where the 'Genre' column is not empty
selected_genre_df = selected_columns[selected_columns['Genre'] != ""]

# Now, you can group the DataFrame by the 'Genre' column
grouped_by_genre = selected_genre_df.groupby("Genre")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 5
#       2 selected_genre_df = tomatoes_data.stack().reset_index()
#       4 # Access columns using double square brackets
# ----> 5 selected_columns = selected_genre_df[['Series or Movie','column','Genre']]
#       7 # Filter rows where the 'Genre' column is not empty
#       8 selected_genre_df = selected_columns[selected_columns['Genre'] != ""]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
# merging netflix and tomatoes data sets
netflix_tomatoes_data = pd.merge(netflix_data, tomatoes_data, how="left", on=['Title','Series or Movie','Genre'])
netflix_tomatoes_data.head()

# %%
# Calculate the total number of movies
title_count = len(netflix_tomatoes_data["Title"].unique())
title_count

# %%
# Calculate the total number tv shows
genre_count = len(netflix_tomatoes_data["Genre"].unique())
genre_count

# %%
scores_df = tomatoes_data[['Rotten Tomatoes Score', 'Metacritic Score', 'Awards Received', 'Awards Nominated For']]
scores_df = scores_df.fillna('')
scores_df

# %%
for scores in scores_list:
    # Filter the data for the specific treatment
    subset_data = clean_data[clean_data["Drug Regimen"] == treatment]["Tumor Volume (mm3)"]
    
    # Calculate the IQR
    quartiles = subset_data.quantile([0.25, 0.75])
    lower_q = quartiles[0.25]
    upper_q = quartiles[0.75]
    iqr = upper_q - lower_q
    
    # Determine the lower and upper bounds for potential outliers
    lower_bound = lower_q - 1.5 * iqr
    upper_bound = upper_q + 1.5 * iqr
    
    # potential outliers
    outliers = subset_data[(subset_data < lower_bound) | (subset_data > upper_bound)]
    
    # tumor volume data for the current treatment
    tumor_vol_data[treatment] = subset_data
    
    # potential outliers for the current treatment
    potential_outliers[treatment] = outliers

treatment_list
tumor_vol_data
potential_outliers

# %%
# Assuming you have defined variables like Drama, Thriller, Horror, and Comedy with data
Drama_movies = netflix_tomatoes_data[netflix_tomatoes_data["Genre"] == 'Rotten Tomatoes Score']
Thriller_movies = netflix_tomatoes_data[netflix_tomatoes_data["Genre"] == 'Rotten Tomatoes Score']
Horror_movies = netflix_tomatoes_data[netflix_tomatoes_data["Genre"] == 'Rotten Tomatoes Score']
Comedy_movies = netflix_tomatoes_data[netflix_tomatoes_data["Genre"] == 'Rotten Tomatoes Score']

# Calculate the lengths or counts of these variables
count_drama = len(Drama_movies)
count_thriller = len(Thriller_movies)
count_horror = len(Horror_movies)
count_comedy = len(Comedy_movies)

# Define the x-values as a range based on the counts
x = range(max(count_drama, count_thriller, count_horror, count_comedy))

# Assuming title_count and genre_count are also defined with appropriate data
plt.stackplot(x, title_count, genre_count, labels=['Genre', 'Title'])
plt.xlabel('Genre')
plt.ylabel('Title Count')
plt.legend()
plt.show()

# %%
column_to_print = netflix_tomatoes_data["Genre"]
print(column_to_print)

# %%
#genre types in netflix data 
genre_types = netflix_tomatoes_data[["Genre",]].set_index("Genre")
genre_types

# %%
# Create a bar chart listing the value counts for multiple genres
genres = ['Documentaries', 'International', 'Dramas', 'Comedies', 'Horror', 'Musicals']
counts = netflix_tomatoes_data[genre_types].value_counts()

# Plot the bar chart
plt.bar(counts.index, counts.values)
plt.xlabel('Series or Movie Genre')
plt.ylabel('Count')
plt.title('Genres')
plt.show()

# %%
#create a bar chart listing the genre types in each data set 
counts = netflix_tomatoes_data["Series or Movie"].value_counts()
plt.bar(counts.index.values,counts.values)
plt.xlabel('Series or Movie')
plt.xticks(rotation=90)
plt.ylabel('Genre')
plt.show()

# %%
# genre types in tomatoes data
genre_tom_types = tomatoes_data[["Genre", "Series or Movie"]].set_index("Genre")["Series or Movie"]
genre_tom_types

# %%
#genre types in both data combined
# Checking the number of genres in the clean DataFrame.
genre_netflix_types = netflix_data[['Genre', "Series or Movie"]].set_index('Genre')["Series or Movie"]
genre_netflix_types

# %%
netflix_tomatoes_data.columns

# %%
# Generate a pie plot showing the distribution of Series or Movie and listed_in using pyplot
counts = netflix_tomatoes_data["Series or Movie"].value_counts()
plt.pie(counts.values, labels=counts.index.values, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Movie or Series")
plt.xlabel("Genres")
plt.ylabel("Series or Movie")
plt.axis('equal')
plt.show()

# %%
# Define a list of treatments for the for loop
genre_type = ['Crime', 'Drama', 'Fantasy', 'Horror', 'Romance']

# Create a dictionary to store potential outliers
potential_outliers = {}

# Iterate through each movie genre

for genre in genre_type:
   
    outliers = netflix_tomatoes_data[(netflix_tomatoes_data['Genre'] == genre) &
                                     ((netflix_tomatoes_data[genre] < lower_bound) | (netflix_tomatoes_data[genre] > upper_bound))]
    netflix_tomatoes_data[genre + '_outlier'] = False
    netflix_tomatoes_data.loc[outliers.index, genre + '_outlier'] = True
    
    # Perform your analysis or outlier detection for the specific genre here
     # Calculate the IQR
    quartiles = netflix_tomatoes_data.quantile([0.25, 0.75])
    lower_q = quartiles.loc[0.25]  
    upper_q = quartiles.loc[0.75]  
    iqr = upper_q - lower_q
    
    # Determine the lower and upper bounds for potential outliers
    lower_bound = lower_q - 1.5 * iqr
    upper_bound = upper_q + 1.5 * iqr
    
    # potential outliers
    outliers = netflix_tomatoes_data[(netflix_tomatoes_data < lower_bound) | (netflix_tomatoes_data > upper_bound)]
  




    # Store the results in the potential_outliers dictionary
    potential_outliers[genre] = genre_data

# %%
# Define your DataFrame (replace this with your actual DataFrame)
tomatoes_data = pd.DataFrame({
    'Genre': ['Drama', 'Comedy', 'Horror', 'Action'],
    'Drama': [1, 0, 0, 0],
    'Comedy': [0, 1, 0, 0],
    'Horror': [0, 0, 1, 0],
    'Action': [0, 0, 0, 1]
})

# Specify the genre you want to analyze (e.g., 'Crime' in your case)
genre_type = 'Drama','Comedy'

# Check if the genre exists in the DataFrame
if genre_type in netflix_tomatoes_data.columns:
    # Calculate lower and upper bounds (you should have these values defined)
    lower_bound = 0
    upper_bound = 1

    # Identify outliers for the specified genre
    outliers = netflix_tomatoes_data[
        (tomatoes_data['Genre'] == genre_type) &
        ((tomatoes_data[genre_type] < lower_bound) | (tomatoes_data[genre_type] > upper_bound))
    ]

    # Create a new column to mark outliers for that genre
    tomatoes_data[genre_type + '_outlier'] = False
    tomatoes_data.loc[outliers.index, genre_type + '_outlier'] = True

else:
    print(f"Genre '{genre_type}' does not exist in the DataFrame.")

# %%
# Generate a box plot that shows movies and what genres they're in 
# Dramas, Thrillers, Horror, and Comedy

Drama_movies = netflix_tomatoes_data [netflix_tomatoes_data['description'] == "Drama_movies"]["Genre"]
Thriller_movies = netflix_tomatoes_data [netflix_tomatoes_data['description'] == "Thriller_movies"]["Genre"]
Horror_movies =netflix_tomatoes_data [netflix_tomatoes_data['description'] == "Horror_movies"]["Genre"]
Comedy_movies = netflix_tomatoes_data [netflix_tomatoes_data['description'] == "Comedy_movies"]["Genre"]


# Create a list of tumor volume data for each treatment group
movie_data = [Drama_movies, Thriller_movies, Horror_movies, Comedy_movies]

# Create a boxplot
plt.boxplot(movie_data, showmeans=True)
plt.grid(True)
plt.title("Movie Types")
plt.ylabel('description')
plt.xticks([1, 2, 3, 4], ["Drama_movies", "Thriller_movies", "Horror_movies", "Comedy_movies"])
plt.show()

# %%
# Filter the DataFrame for each genre
Drama_movies = netflix_tomatoes_data[netflix_tomatoes_data['Genre'] == "Drama"]
Thriller_movies = netflix_tomatoes_data[netflix_tomatoes_data['Genre'] == "Thriller"]
Horror_movies = netflix_tomatoes_data[netflix_tomatoes_data['Genre'] == "Horror"]
Comedy_movies = netflix_tomatoes_data[netflix_tomatoes_data['Genre'] == "Comedy"]

# Count the occurrences of each genre and create a DataFrame
genre_counts = pd.DataFrame({
    'Genre': ['Drama', 'Thriller', 'Horror', 'Comedy'],
    'Count': [Drama_movies.shape[0], Thriller_movies.shape[0], Horror_movies.shape[0], Comedy_movies.shape[0]]
})

# Create a bar plot
plt.scatter(genre_counts['Genre'], genre_counts['Count'])

plt.xlabel('Genre')
plt.ylabel('Count')
plt.title('Counts of Genres')

# Display the plot
plt.show()

# %%
  genre_counts = pd.DataFrame({
    'Genre': ['Drama_movies', 'Thriller_movies', 'Horror_movies', 'Comedy_movies'],
    'Count': [Drama_movies.shape[0], Thriller_movies.shape[0], Horror_movies.shape[0], Comedy_movies.shape[0]]
})
genre_counts = genre_counts[genres_to_count].sum()
# Create a scatter plot
plt.scatter(genre_counts['Genre'], genre_counts['Count'])

# Set labels and title
plt.xlabel('Genre')
plt.ylabel('Count')
plt.title('Counts of Genres')

# Rotate the x-axis labels for better visibility
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
# Calculate the average rating per type
count_by_listed_in = netflix_data['rating'].value_counts()
count_by_listed_in

# %%
# Generate a bar plot showing the total number of rows (Genre/listed_in) using pyplot.

counts = netflix_tomatoes_data['rating'].value_counts()
plt.bar(counts.index.values,counts.values)
plt.xlabel('rating')
plt.xticks(rotation=90)
plt.ylabel("listed_in")
plt.show()

# %%
count_by_type = netflix_data['Series or Movie'].value_counts()
count_by_type

# %%
count_tom_type = tomatoes_data['Series or Movie'].value_counts()
count_tom_type

# %%
Drama_movies = netflix_tomatoes_data[netflix_tomatoes_data['Genre'] == "Drama_movies"]
Thriller_movies = netflix_tomatoes_data[netflix_tomatoes_data['Genre'] == "Thriller_movies"]
Horror_movies = netflix_tomatoes_data[netflix_tomatoes_data['Genre'] == "Horror_movies"]
Comedy_movies = netflix_tomatoes_data[netflix_tomatoes_data['Genre'] == "Comedy_movies"]

# Create a bar plot to visualize the counts
genre_counts = [len(Drama_movies), len(Thriller_movies), len(Horror_movies), len(Comedy_movies)]
genres = ['Drama_movies', 'Thriller_movies', 'Horror_movies', 'Comedy_movies']


plt.bar(counts.index.values,counts.values)
# Set labels and title
plt.xlabel('Genre')
plt.ylabel('Count')
plt.title('Count of Movies in Different Genres')

# Show the plot

# %%
Drama_movies = tomatoes_data[netflix_tomatoes_data['Genre'] == "Drama_movies"]
Comedy_movies = tomatoes_data[netflix_tomatoes_data['Genre'] == "Comedy_movies"]
counts = tomatoes_data['Genre'].value_counts()

plt.scatter(counts.index.values,counts.values)
plt.xlabel('Genre')
plt.xticks(rotation=90)
plt.ylabel('View Rating')
plt.show()

# %%
# Create a list of genres to count
tomatoes_data = [{'Title': 'Movie 1', 'Genre': 'Drama'}, {'Title': 'Movie 2', 'Genre': 'Thriller'}]
df = pd.DataFrame(tomatoes_data)

# Now you can filter the DataFrame using column values
Drama_movies = df[df['Genre'] == 'Drama']
Thriller_movies = df[df['Genre'] == 'Thriller']
genres_to_count = ['Drama', 'Thriller', 'Horror', 'Comedy']

# Create a new column 'Any_Genre' which is True if any of the specified genres are present, otherwise False
df['Any_Genre'] = df[genres_to_count].apply(lambda x: any(x), axis=1)

# Filter the DataFrame based on the 'Any_Genre' column
filtered_data = df[df['Any_Genre']]

# Count the occurrences of each genre in the filtered data
genre_counts = filtered_data[genres_to_count].sum()

# %%
counts_drama = tomatoes_data['Genre'].value_counts()

# Create a line plot
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
counts_drama.plot(kind='line', marker='o', linestyle='-', color='b')

# Set labels
plt.xlabel("Genre")
plt.ylabel("Count")

# Optionally, set the x-axis ticks to match your data
plt.xticks(rotation=90)

# Show the plot
plt.show()

# %%
counts_drama = tomatoes_data['Genre'].value_counts()
counts_drama = tomatoes_data.value_counts()
counts_thriller = tomatoes_data.value_counts()
counts_horror = tomatoes_data.value_counts()
counts_comedy = tomatoes_data.value_counts()
# Generate a line plot of Series vs. Movie 
counts = tomatoes_data["counts_drama, counts_thriller, counts_horror, counts_comedy"].value_counts()

# Create a scatter plot
plt.line(counts.index, counts.values)

# Set labels
plt.xlabel("Type")
plt.ylabel("Count")

# Optionally, set the x-axis ticks to match your data
plt.xticks(rotation=90)

# Show the plot
plt.show()

# %%
data_list = [
    {'Title': 'Movie1', 'Genre': 'Drama', 'Tags': 'Tag1'},
    {'Title': 'Movie2', 'Genre': 'Thriller', 'Tags': 'Tag2'},
    {'Title': 'Movie3', 'Genre': 'Horror', 'Tags': 'Tag3'},
    # Add more data as needed
]

# Create a DataFrame from the list of dictionaries
tomatoes_data = pd.DataFrame(data_list)

# Now, you can calculate value counts for the 'Genre' column
counts_drama = tomatoes_data['Genre'].value_counts()

# %%
Drama_movies = netflix_tomatoes_data[netflix_tomatoes_data['Genre'] == "Drama"]
Thriller_movies = netflix_tomatoes_data[netflix_tomatoes_data['Genre'] == "Thriller"]
Horror_movies = netflix_tomatoes_data[netflix_tomatoes_data['Genre'] == "Horror"]
Comedy_movies = netflix_tomatoes_data[netflix_tomatoes_data['Genre'] == "Comedy"]

# Data for plotting
plot_data = [Drama_movies, Thriller_movies, Horror_movies, Comedy_movies]
tomatoes_data = ["Drama_movies, Thriller_movies, Horror_movies, Comedy_movies"]

# Create a box plot
fig1, ax1 = plt.subplots()
ax1.set_title('Genre Types')
ax1.set_ylabel('Number of Genres')
ax1.set_xlabel('Movie Type')
ax1.boxplot(plot_data, widths=0.4, vert=True, labels=['Drama', 'Thriller', 'Horror', 'Comedy'])
plt.show()
